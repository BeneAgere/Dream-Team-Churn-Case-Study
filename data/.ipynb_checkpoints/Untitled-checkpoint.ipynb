# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
df = pd.read_csv('churn.csv',parse_dates=['last_trip_date','signup_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
# avg_dist                  50000 non-null float64
# avg_rating_by_driver      49799 non-null float64
# avg_rating_of_driver      41878 non-null float64
# avg_surge                 50000 non-null float64
# city                      50000 non-null object
# last_trip_date            50000 non-null datetime64[ns]
# phone                     49604 non-null object
# signup_date               50000 non-null datetime64[ns]
# surge_pct                 50000 non-null float64
# trips_in_first_30_days    50000 non-null int64
# luxury_car_user           50000 non-null bool
# weekday_pct               50000 non-null float64
# dtypes: bool(1), datetime64[ns](2), float64(6), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
df.head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days  ...   weekday_pct  Android  iPhone  others  \
# 0                       4  ...          46.2      0.0     1.0     0.0
# ...

# %%
type(df['signup_date'][0])
# Out:
# pandas.tslib.Timestamp

# %%
df.cov()
# Out:
#                          avg_dist  avg_rating_by_driver  avg_rating_of_driver  \
# avg_dist                32.573921              0.203818              0.109752
# avg_rating_by_driver     0.203818              0.199498              0.030666
# avg_rating_of_driver     0.109752              0.030666              0.381107
# avg_surge               -0.103409              0.001045             -0.003247
# surge_pct              -11.893989              0.178330             -0.044296
# trips_in_first_30_days  -2.950994             -0.066365             -0.028295
# luxury_car_user          0.089374              0.002023             -0.000626
# weekday_pct             21.513372              0.337995              0.314834
#
#                         avg_surge   surge_pct  trips_in_first_30_days  \
# avg_dist                -0.103409  -11.893989               -2.950994
# avg_rating_by_driver     0.001045    0.178330               -0.066365
# ...

# %%
df.corr()
# Out:
#                         avg_dist  avg_rating_by_driver  avg_rating_of_driver  \
# avg_dist                1.000000              0.080540              0.034509
# avg_rating_by_driver    0.080540              1.000000              0.123175
# avg_rating_of_driver    0.034509              0.123175              1.000000
# avg_surge              -0.081491              0.010597             -0.026189
# surge_pct              -0.104414              0.020103             -0.003899
# trips_in_first_30_days -0.136329             -0.039115             -0.011302
# luxury_car_user         0.032310              0.009343             -0.002086
# weekday_pct             0.101652              0.020442              0.014630
#
#                         avg_surge  surge_pct  trips_in_first_30_days  \
# avg_dist                -0.081491  -0.104414               -0.136329
# avg_rating_by_driver     0.010597   0.020103               -0.039115
# ...

# %%
df['city'].unique()
# Out:
# array(["King's Landing", 'Astapor', 'Winterfell'], dtype=object)

# %%
df['avg_rating_by_driver'] = df['avg_rating_by_driver'].fillna(df['avg_rating_by_driver'].sum()*1.0/len(df['avg_rating_by_driver']))

# %%
df['avg_rating_of_driver'] = df['avg_rating_of_driver'].fillna(df['avg_rating_of_driver'].sum()*1.0/len(df['avg_rating_of_driver']))

# %%
df['phone'] = df['phone'].fillna('others')

# %%
df = pd.concat((df, pd.get_dummies(df['phone']), pd.get_dummies(df['city']),pd.get_dummies(df['luxury_car_user'])), axis=1)

# %%
df.head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days  ...   weekday_pct  Android  iPhone  others  \
# 0                       4  ...          46.2      0.0     1.0     0.0
# ...

# %%
df['churn'] = datetime(2014, 7, 1) - df['last_trip_date'] <= timedelta(days=30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
# avg_dist                  50000 non-null float64
# avg_rating_by_driver      50000 non-null float64
# avg_rating_of_driver      50000 non-null float64
# avg_surge                 50000 non-null float64
# city                      50000 non-null object
# last_trip_date            50000 non-null datetime64[ns]
# phone                     50000 non-null object
# signup_date               50000 non-null datetime64[ns]
# surge_pct                 50000 non-null float64
# trips_in_first_30_days    50000 non-null int64
# luxury_car_user           50000 non-null bool
# weekday_pct               50000 non-null float64
# Android                   50000 non-null float64
# iPhone                    50000 non-null float64
# others                    50000 non-null float64
# Astapor                   50000 non-null float64
# King's Landing            50000 non-null float64
# ...

# %%
df.rename(columns={'True': 'Luxury_car_user', 'False': 'Non_luxury_car_user'}, inplace=True)

# %%
df.head()
# Out:
#    avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0      3.67                   5.0                   4.7       1.10
# 1      8.26                   5.0                   5.0       1.00
# 2      0.77                   5.0                   4.3       1.00
# 3      2.36                   4.9                   4.6       1.14
# 4      3.13                   4.9                   4.4       1.19
#
#              city last_trip_date    phone signup_date  surge_pct  \
# 0  King's Landing     2014-06-17   iPhone  2014-01-25       15.4
# 1         Astapor     2014-05-05  Android  2014-01-29        0.0
# 2         Astapor     2014-01-07   iPhone  2014-01-06        0.0
# 3  King's Landing     2014-06-29   iPhone  2014-01-10       20.0
# 4      Winterfell     2014-03-15  Android  2014-01-27       11.8
#
#    trips_in_first_30_days  ...   weekday_pct  Android  iPhone  others  \
# 0                       4  ...          46.2      0.0     1.0     0.0
# ...

# %%
from statsmodels.graphics.correlation import plot_corr
import matplotlib.pyplot as plt

# %%
sum(df['churn'] == 0)
# Out:
# 31196

# %%
df.corr()
# Out:
#                         avg_dist  avg_rating_by_driver  avg_rating_of_driver  \
# avg_dist                1.000000              0.079781             -0.032230
# avg_rating_by_driver    0.079781              1.000000              0.088048
# avg_rating_of_driver   -0.032230              0.088048              1.000000
# avg_surge              -0.081491              0.010427             -0.022453
# surge_pct              -0.104414              0.019904             -0.000040
# trips_in_first_30_days -0.136329             -0.039018              0.075864
# luxury_car_user         0.032310              0.009403              0.014354
# weekday_pct             0.101652              0.020402              0.021078
# Android                 0.020888              0.008762             -0.001475
# iPhone                 -0.025030             -0.010122              0.002832
# others                  0.022372              0.007419             -0.007122
# ...

# %%
pd.scatter_matrix(df, alpha=0.2, figsize=(15,15), diagonal='kde')
plt.show()

# %%
plt.matshow(df.corr())
plt.show()
